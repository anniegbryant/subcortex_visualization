# %% [markdown]
# ## Render generated `.obj` mesh files as one interactive 3D image

# %%
# Import necessary libraries
import nibabel as nib
import numpy as np
from skimage import measure
import pyvista as pv
from matplotlib import cm
import matplotlib.colors as mcolors
from scipy.ndimage import gaussian_filter
import os
from glob import glob

# %%
# Filter subcortex
subcortex_file = 'atlas_aicha_subcortex.nii.gz'
subcortex_file_L = 'atlas_aicha_subcortex_L.nii.gz'
subcortex_file_R = 'atlas_aicha_subcortex_R.nii.gz'

if not os.path.isfile(subcortex_file):

    # Set your input and output file paths
    input_file = 'atlas_aicha.nii.gz'

    # Load the NIfTI file
    img = nib.load(input_file)
    data = img.get_fdata()

    # Create a mask for the desired range (inclusive)
    mask = (data >= 345) & (data <= 384)

    # For left hemisphere, take odd numbers between 345 and 384 inclusive
    left_mask = (data >= 345) & (data <= 384) & (data % 2 == 1)
    # For right hemisphere, take even numbers between 345 and 384 inclusive
    right_mask = (data >= 345) & (data <= 384) & (data % 2 == 0)

    # Set values outside the range to 0, keep values inside unchanged
    filtered_data = np.where(mask, data, 0)
    filtered_data_L = np.where(left_mask, data, 0)
    filtered_data_R = np.where(right_mask, data, 0)

    # Save the filtered data as a new NIfTI file
    filtered_img = nib.Nifti1Image(filtered_data, img.affine, img.header)
    filtered_img_L = nib.Nifti1Image(filtered_data_L, img.affine, img.header)
    filtered_img_R = nib.Nifti1Image(filtered_data_R, img.affine, img.header)

    # Save the filtered data as a new NIfTI file
    nib.save(filtered_img, subcortex_file)
    print(f"Filtered both hemispheres saved as {subcortex_file}")

    nib.save(filtered_img_L, subcortex_file_L)
    print(f"Filtered left hemisphere saved as {subcortex_file_L}")

    nib.save(filtered_img_R, subcortex_file_R)
    print(f"Filtered right hemisphere saved as {subcortex_file_R}")
# Out:
# Filtered both hemispheres saved as atlas_aicha_subcortex.nii.gz
# Filtered left hemisphere saved as atlas_aicha_subcortex_L.nii.gz
# Filtered right hemisphere saved as atlas_aicha_subcortex_R.nii.gz

# %%
# %%bash
#
# source ~/.bashrc
# nii2mesh atlas_aicha_subcortex.nii.gz -b 1 -l 0 -q 2 -r 0.01 -s 10 -a 1 individual_meshes/atlas_aicha_subcortex.obj
# Out:
# 1/384
# Skipping 1: no voxels with this intensity
# 2/384
# Skipping 2: no voxels with this intensity
# 3/384
# Skipping 3: no voxels with this intensity
# 4/384
# Skipping 4: no voxels with this intensity
# 5/384
# Skipping 5: no voxels with this intensity
# 6/384
# Skipping 6: no voxels with this intensity
# 7/384
# Skipping 7: no voxels with this intensity
# 8/384
# Skipping 8: no voxels with this intensity
# 9/384
# Skipping 9: no voxels with this intensity
# 10/384
# Skipping 10: no voxels with this intensity
# 11/384
# Skipping 11: no voxels with this intensity
# 12/384
# Skipping 12: no voxels with this intensity
# 13/384
# Skipping 13: no voxels with this intensity
# 14/384
# Skipping 14: no voxels with this intensity
# 15/384
# Skipping 15: no voxels with this intensity
# 16/384
# Skipping 16: no voxels with this intensity
# 17/384
# Skipping 17: no voxels with this intensity
# 18/384
# Skipping 18: no voxels with this intensity
# 19/384
# Skipping 19: no voxels with this intensity
# 20/384
# Skipping 20: no voxels with this intensity
# 21/384
# Skipping 21: no voxels with this intensity
# 22/384
# Skipping 22: no voxels with this intensity
# 23/384
# Skipping 23: no voxels with this intensity
# 24/384
# Skipping 24: no voxels with this intensity
# 25/384
# Skipping 25: no voxels with this intensity
# 26/384
# Skipping 26: no voxels with this intensity
# 27/384
# Skipping 27: no voxels with this intensity
# 28/384
# Skipping 28: no voxels with this intensity
# 29/384
# Skipping 29: no voxels with this intensity
# 30/384
# Skipping 30: no voxels with this intensity
# 31/384
# Skipping 31: no voxels with this intensity
# 32/384
# Skipping 32: no voxels with this intensity
# 33/384
# Skipping 33: no voxels with this intensity
# 34/384
# Skipping 34: no voxels with this intensity
# 35/384
# Skipping 35: no voxels with this intensity
# 36/384
# Skipping 36: no voxels with this intensity
# 37/384
# Skipping 37: no voxels with this intensity
# 38/384
# Skipping 38: no voxels with this intensity
# 39/384
# Skipping 39: no voxels with this intensity
# 40/384
# Skipping 40: no voxels with this intensity
# 41/384
# Skipping 41: no voxels with this intensity
# 42/384
# Skipping 42: no voxels with this intensity
# 43/384
# Skipping 43: no voxels with this intensity
# 44/384
# Skipping 44: no voxels with this intensity
# 45/384
# Skipping 45: no voxels with this intensity
# 46/384
# Skipping 46: no voxels with this intensity
# 47/384
# Skipping 47: no voxels with this intensity
# 48/384
# Skipping 48: no voxels with this intensity
# 49/384
# Skipping 49: no voxels with this intensity
# 50/384
# Skipping 50: no voxels with this intensity
# 51/384
# Skipping 51: no voxels with this intensity
# 52/384
# Skipping 52: no voxels with this intensity
# 53/384
# Skipping 53: no voxels with this intensity
# 54/384
# Skipping 54: no voxels with this intensity
# 55/384
# Skipping 55: no voxels with this intensity
# 56/384
# Skipping 56: no voxels with this intensity
# 57/384
# Skipping 57: no voxels with this intensity
# 58/384
# Skipping 58: no voxels with this intensity
# 59/384
# Skipping 59: no voxels with this intensity
# 60/384
# Skipping 60: no voxels with this intensity
# 61/384
# Skipping 61: no voxels with this intensity
# 62/384
# Skipping 62: no voxels with this intensity
# 63/384
# Skipping 63: no voxels with this intensity
# 64/384
# Skipping 64: no voxels with this intensity
# 65/384
# Skipping 65: no voxels with this intensity
# 66/384
# Skipping 66: no voxels with this intensity
# 67/384
# Skipping 67: no voxels with this intensity
# 68/384
# Skipping 68: no voxels with this intensity
# 69/384
# Skipping 69: no voxels with this intensity
# 70/384
# Skipping 70: no voxels with this intensity
# 71/384
# Skipping 71: no voxels with this intensity
# 72/384
# Skipping 72: no voxels with this intensity
# 73/384
# Skipping 73: no voxels with this intensity
# 74/384
# Skipping 74: no voxels with this intensity
# 75/384
# Skipping 75: no voxels with this intensity
# 76/384
# Skipping 76: no voxels with this intensity
# 77/384
# Skipping 77: no voxels with this intensity
# 78/384
# Skipping 78: no voxels with this intensity
# 79/384
# Skipping 79: no voxels with this intensity
# 80/384
# Skipping 80: no voxels with this intensity
# 81/384
# Skipping 81: no voxels with this intensity
# 82/384
# Skipping 82: no voxels with this intensity
# 83/384
# Skipping 83: no voxels with this intensity
# 84/384
# Skipping 84: no voxels with this intensity
# 85/384
# Skipping 85: no voxels with this intensity
# 86/384
# Skipping 86: no voxels with this intensity
# 87/384
# Skipping 87: no voxels with this intensity
# 88/384
# Skipping 88: no voxels with this intensity
# 89/384
# Skipping 89: no voxels with this intensity
# 90/384
# Skipping 90: no voxels with this intensity
# 91/384
# Skipping 91: no voxels with this intensity
# 92/384
# Skipping 92: no voxels with this intensity
# 93/384
# Skipping 93: no voxels with this intensity
# 94/384
# Skipping 94: no voxels with this intensity
# 95/384
# Skipping 95: no voxels with this intensity
# 96/384
# Skipping 96: no voxels with this intensity
# 97/384
# Skipping 97: no voxels with this intensity
# 98/384
# Skipping 98: no voxels with this intensity
# 99/384
# Skipping 99: no voxels with this intensity
# 100/384
# Skipping 100: no voxels with this intensity
# 101/384
# Skipping 101: no voxels with this intensity
# 102/384
# Skipping 102: no voxels with this intensity
# 103/384
# Skipping 103: no voxels with this intensity
# 104/384
# Skipping 104: no voxels with this intensity
# 105/384
# Skipping 105: no voxels with this intensity
# 106/384
# Skipping 106: no voxels with this intensity
# 107/384
# Skipping 107: no voxels with this intensity
# 108/384
# Skipping 108: no voxels with this intensity
# 109/384
# Skipping 109: no voxels with this intensity
# 110/384
# Skipping 110: no voxels with this intensity
# 111/384
# Skipping 111: no voxels with this intensity
# 112/384
# Skipping 112: no voxels with this intensity
# 113/384
# Skipping 113: no voxels with this intensity
# 114/384
# Skipping 114: no voxels with this intensity
# 115/384
# Skipping 115: no voxels with this intensity
# 116/384
# Skipping 116: no voxels with this intensity
# 117/384
# Skipping 117: no voxels with this intensity
# 118/384
# Skipping 118: no voxels with this intensity
# 119/384
# Skipping 119: no voxels with this intensity
# 120/384
# Skipping 120: no voxels with this intensity
# 121/384
# Skipping 121: no voxels with this intensity
# 122/384
# Skipping 122: no voxels with this intensity
# 123/384
# Skipping 123: no voxels with this intensity
# 124/384
# Skipping 124: no voxels with this intensity
# 125/384
# Skipping 125: no voxels with this intensity
# 126/384
# Skipping 126: no voxels with this intensity
# 127/384
# Skipping 127: no voxels with this intensity
# 128/384
# Skipping 128: no voxels with this intensity
# 129/384
# Skipping 129: no voxels with this intensity
# 130/384
# Skipping 130: no voxels with this intensity
# 131/384
# Skipping 131: no voxels with this intensity
# 132/384
# Skipping 132: no voxels with this intensity
# 133/384
# Skipping 133: no voxels with this intensity
# 134/384
# Skipping 134: no voxels with this intensity
# 135/384
# Skipping 135: no voxels with this intensity
# 136/384
# Skipping 136: no voxels with this intensity
# 137/384
# Skipping 137: no voxels with this intensity
# 138/384
# Skipping 138: no voxels with this intensity
# 139/384
# Skipping 139: no voxels with this intensity
# 140/384
# Skipping 140: no voxels with this intensity
# 141/384
# Skipping 141: no voxels with this intensity
# 142/384
# Skipping 142: no voxels with this intensity
# 143/384
# Skipping 143: no voxels with this intensity
# 144/384
# Skipping 144: no voxels with this intensity
# 145/384
# Skipping 145: no voxels with this intensity
# 146/384
# Skipping 146: no voxels with this intensity
# 147/384
# Skipping 147: no voxels with this intensity
# 148/384
# Skipping 148: no voxels with this intensity
# 149/384
# Skipping 149: no voxels with this intensity
# 150/384
# Skipping 150: no voxels with this intensity
# 151/384
# Skipping 151: no voxels with this intensity
# 152/384
# Skipping 152: no voxels with this intensity
# 153/384
# Skipping 153: no voxels with this intensity
# 154/384
# Skipping 154: no voxels with this intensity
# 155/384
# Skipping 155: no voxels with this intensity
# 156/384
# Skipping 156: no voxels with this intensity
# 157/384
# Skipping 157: no voxels with this intensity
# 158/384
# Skipping 158: no voxels with this intensity
# 159/384
# Skipping 159: no voxels with this intensity
# 160/384
# Skipping 160: no voxels with this intensity
# 161/384
# Skipping 161: no voxels with this intensity
# 162/384
# Skipping 162: no voxels with this intensity
# 163/384
# Skipping 163: no voxels with this intensity
# 164/384
# Skipping 164: no voxels with this intensity
# 165/384
# Skipping 165: no voxels with this intensity
# 166/384
# Skipping 166: no voxels with this intensity
# 167/384
# Skipping 167: no voxels with this intensity
# 168/384
# Skipping 168: no voxels with this intensity
# 169/384
# Skipping 169: no voxels with this intensity
# 170/384
# Skipping 170: no voxels with this intensity
# 171/384
# Skipping 171: no voxels with this intensity
# 172/384
# Skipping 172: no voxels with this intensity
# 173/384
# Skipping 173: no voxels with this intensity
# 174/384
# Skipping 174: no voxels with this intensity
# 175/384
# Skipping 175: no voxels with this intensity
# 176/384
# Skipping 176: no voxels with this intensity
# 177/384
# Skipping 177: no voxels with this intensity
# 178/384
# Skipping 178: no voxels with this intensity
# 179/384
# Skipping 179: no voxels with this intensity
# 180/384
# Skipping 180: no voxels with this intensity
# 181/384
# Skipping 181: no voxels with this intensity
# 182/384
# Skipping 182: no voxels with this intensity
# 183/384
# Skipping 183: no voxels with this intensity
# 184/384
# Skipping 184: no voxels with this intensity
# 185/384
# Skipping 185: no voxels with this intensity
# 186/384
# Skipping 186: no voxels with this intensity
# 187/384
# Skipping 187: no voxels with this intensity
# 188/384
# Skipping 188: no voxels with this intensity
# 189/384
# Skipping 189: no voxels with this intensity
# 190/384
# Skipping 190: no voxels with this intensity
# 191/384
# Skipping 191: no voxels with this intensity
# 192/384
# Skipping 192: no voxels with this intensity
# 193/384
# Skipping 193: no voxels with this intensity
# 194/384
# Skipping 194: no voxels with this intensity
# 195/384
# Skipping 195: no voxels with this intensity
# 196/384
# Skipping 196: no voxels with this intensity
# 197/384
# Skipping 197: no voxels with this intensity
# 198/384
# Skipping 198: no voxels with this intensity
# 199/384
# Skipping 199: no voxels with this intensity
# 200/384
# Skipping 200: no voxels with this intensity
# 201/384
# Skipping 201: no voxels with this intensity
# 202/384
# Skipping 202: no voxels with this intensity
# 203/384
# Skipping 203: no voxels with this intensity
# 204/384
# Skipping 204: no voxels with this intensity
# 205/384
# Skipping 205: no voxels with this intensity
# 206/384
# Skipping 206: no voxels with this intensity
# 207/384
# Skipping 207: no voxels with this intensity
# 208/384
# Skipping 208: no voxels with this intensity
# 209/384
# Skipping 209: no voxels with this intensity
# 210/384
# Skipping 210: no voxels with this intensity
# 211/384
# Skipping 211: no voxels with this intensity
# 212/384
# Skipping 212: no voxels with this intensity
# 213/384
# Skipping 213: no voxels with this intensity
# 214/384
# Skipping 214: no voxels with this intensity
# 215/384
# Skipping 215: no voxels with this intensity
# 216/384
# Skipping 216: no voxels with this intensity
# 217/384
# Skipping 217: no voxels with this intensity
# 218/384
# Skipping 218: no voxels with this intensity
# 219/384
# Skipping 219: no voxels with this intensity
# 220/384
# Skipping 220: no voxels with this intensity
# 221/384
# Skipping 221: no voxels with this intensity
# 222/384
# Skipping 222: no voxels with this intensity
# 223/384
# Skipping 223: no voxels with this intensity
# 224/384
# Skipping 224: no voxels with this intensity
# 225/384
# Skipping 225: no voxels with this intensity
# 226/384
# Skipping 226: no voxels with this intensity
# 227/384
# Skipping 227: no voxels with this intensity
# 228/384
# Skipping 228: no voxels with this intensity
# 229/384
# Skipping 229: no voxels with this intensity
# 230/384
# Skipping 230: no voxels with this intensity
# 231/384
# Skipping 231: no voxels with this intensity
# 232/384
# Skipping 232: no voxels with this intensity
# 233/384
# Skipping 233: no voxels with this intensity
# 234/384
# Skipping 234: no voxels with this intensity
# 235/384
# Skipping 235: no voxels with this intensity
# 236/384
# Skipping 236: no voxels with this intensity
# 237/384
# Skipping 237: no voxels with this intensity
# 238/384
# Skipping 238: no voxels with this intensity
# 239/384
# Skipping 239: no voxels with this intensity
# 240/384
# Skipping 240: no voxels with this intensity
# 241/384
# Skipping 241: no voxels with this intensity
# 242/384
# Skipping 242: no voxels with this intensity
# 243/384
# Skipping 243: no voxels with this intensity
# 244/384
# Skipping 244: no voxels with this intensity
# 245/384
# Skipping 245: no voxels with this intensity
# 246/384
# Skipping 246: no voxels with this intensity
# 247/384
# Skipping 247: no voxels with this intensity
# 248/384
# Skipping 248: no voxels with this intensity
# 249/384
# Skipping 249: no voxels with this intensity
# 250/384
# Skipping 250: no voxels with this intensity
# 251/384
# Skipping 251: no voxels with this intensity
# 252/384
# Skipping 252: no voxels with this intensity
# 253/384
# Skipping 253: no voxels with this intensity
# 254/384
# Skipping 254: no voxels with this intensity
# 255/384
# Skipping 255: no voxels with this intensity
# 256/384
# Skipping 256: no voxels with this intensity
# 257/384
# Skipping 257: no voxels with this intensity
# 258/384
# Skipping 258: no voxels with this intensity
# 259/384
# Skipping 259: no voxels with this intensity
# 260/384
# Skipping 260: no voxels with this intensity
# 261/384
# Skipping 261: no voxels with this intensity
# 262/384
# Skipping 262: no voxels with this intensity
# 263/384
# Skipping 263: no voxels with this intensity
# 264/384
# Skipping 264: no voxels with this intensity
# 265/384
# Skipping 265: no voxels with this intensity
# 266/384
# Skipping 266: no voxels with this intensity
# 267/384
# Skipping 267: no voxels with this intensity
# 268/384
# Skipping 268: no voxels with this intensity
# 269/384
# Skipping 269: no voxels with this intensity
# 270/384
# Skipping 270: no voxels with this intensity
# 271/384
# Skipping 271: no voxels with this intensity
# 272/384
# Skipping 272: no voxels with this intensity
# 273/384
# Skipping 273: no voxels with this intensity
# 274/384
# Skipping 274: no voxels with this intensity
# 275/384
# Skipping 275: no voxels with this intensity
# 276/384
# Skipping 276: no voxels with this intensity
# 277/384
# Skipping 277: no voxels with this intensity
# 278/384
# Skipping 278: no voxels with this intensity
# 279/384
# Skipping 279: no voxels with this intensity
# 280/384
# Skipping 280: no voxels with this intensity
# 281/384
# Skipping 281: no voxels with this intensity
# 282/384
# Skipping 282: no voxels with this intensity
# 283/384
# Skipping 283: no voxels with this intensity
# 284/384
# Skipping 284: no voxels with this intensity
# 285/384
# Skipping 285: no voxels with this intensity
# 286/384
# Skipping 286: no voxels with this intensity
# 287/384
# Skipping 287: no voxels with this intensity
# 288/384
# Skipping 288: no voxels with this intensity
# 289/384
# Skipping 289: no voxels with this intensity
# 290/384
# Skipping 290: no voxels with this intensity
# 291/384
# Skipping 291: no voxels with this intensity
# 292/384
# Skipping 292: no voxels with this intensity
# 293/384
# Skipping 293: no voxels with this intensity
# 294/384
# Skipping 294: no voxels with this intensity
# 295/384
# Skipping 295: no voxels with this intensity
# 296/384
# Skipping 296: no voxels with this intensity
# 297/384
# Skipping 297: no voxels with this intensity
# 298/384
# Skipping 298: no voxels with this intensity
# 299/384
# Skipping 299: no voxels with this intensity
# 300/384
# Skipping 300: no voxels with this intensity
# 301/384
# Skipping 301: no voxels with this intensity
# 302/384
# Skipping 302: no voxels with this intensity
# 303/384
# Skipping 303: no voxels with this intensity
# 304/384
# Skipping 304: no voxels with this intensity
# 305/384
# Skipping 305: no voxels with this intensity
# 306/384
# Skipping 306: no voxels with this intensity
# 307/384
# Skipping 307: no voxels with this intensity
# 308/384
# Skipping 308: no voxels with this intensity
# 309/384
# Skipping 309: no voxels with this intensity
# 310/384
# Skipping 310: no voxels with this intensity
# 311/384
# Skipping 311: no voxels with this intensity
# 312/384
# Skipping 312: no voxels with this intensity
# 313/384
# Skipping 313: no voxels with this intensity
# 314/384
# Skipping 314: no voxels with this intensity
# 315/384
# Skipping 315: no voxels with this intensity
# 316/384
# Skipping 316: no voxels with this intensity
# 317/384
# Skipping 317: no voxels with this intensity
# 318/384
# Skipping 318: no voxels with this intensity
# 319/384
# Skipping 319: no voxels with this intensity
# 320/384
# Skipping 320: no voxels with this intensity
# 321/384
# Skipping 321: no voxels with this intensity
# 322/384
# Skipping 322: no voxels with this intensity
# 323/384
# Skipping 323: no voxels with this intensity
# 324/384
# Skipping 324: no voxels with this intensity
# 325/384
# Skipping 325: no voxels with this intensity
# 326/384
# Skipping 326: no voxels with this intensity
# 327/384
# Skipping 327: no voxels with this intensity
# 328/384
# Skipping 328: no voxels with this intensity
# 329/384
# Skipping 329: no voxels with this intensity
# 330/384
# Skipping 330: no voxels with this intensity
# 331/384
# Skipping 331: no voxels with this intensity
# 332/384
# Skipping 332: no voxels with this intensity
# 333/384
# Skipping 333: no voxels with this intensity
# 334/384
# Skipping 334: no voxels with this intensity
# 335/384
# Skipping 335: no voxels with this intensity
# 336/384
# Skipping 336: no voxels with this intensity
# 337/384
# Skipping 337: no voxels with this intensity
# 338/384
# Skipping 338: no voxels with this intensity
# 339/384
# Skipping 339: no voxels with this intensity
# 340/384
# Skipping 340: no voxels with this intensity
# 341/384
# Skipping 341: no voxels with this intensity
# 342/384
# Skipping 342: no voxels with this intensity
# 343/384
# Skipping 343: no voxels with this intensity
# 344/384
# Skipping 344: no voxels with this intensity
# 345/384
# 346/384
# 347/384
# Suggested isolevel out of range. Intensity range 0..0.343406, setting isolevel to 0.171703
# 348/384
# Suggested isolevel out of range. Intensity range 0..0.446625, setting isolevel to 0.223312
# 349/384
# Suggested isolevel out of range. Intensity range 0..0.444781, setting isolevel to 0.222391
# 350/384
# 351/384
# 352/384
# 353/384
# 354/384
# 355/384
# 356/384
# 357/384
# 358/384
# 359/384
# Suggested isolevel out of range. Intensity range 0..0.490781, setting isolevel to 0.245391
# 360/384
# 361/384
# 362/384
# 363/384
# 364/384
# 365/384
# 366/384
# 367/384
# 368/384
# 369/384
# 370/384
# 371/384
# 372/384
# 373/384
# 374/384
# 375/384
# 376/384
# 377/384
# 378/384
# 379/384
# Suggested isolevel out of range. Intensity range 0..0.402187, setting isolevel to 0.201094
# 380/384
# Suggested isolevel out of range. Intensity range 0..0.440156, setting isolevel to 0.220078
# 381/384
# 382/384
# 383/384
# 384/384
# Converted 40 regions of interest

# %% [markdown]
# We'll read in the meshes created by the `nii2mesh` program and combine them into one figure.
#
# Note: this code will exclusively render the left hemisphere; if you want to keep both, uncomment line 8 instead of line 7.

# %%
# Path to the folder containing the .obj files
obj_folder = "individual_meshes"

# Find the .obj files in obj_folder
obj_files = glob(os.path.join(obj_folder, "*.obj"))

num_regions = int(len(obj_files)/2)  # Left hemisphere only
# num_regions = int(len(obj_files)) # Uncomment this line to include both hemispheres

# Define the file base for the .obj files
file_base = f"{obj_folder}/atlas_aicha_subcortex"

# List to store meshes
meshes = []

# Generate num_regions colors from the 'plasma' colormap
# You can swap 'plasma' with any other colormap available in matplotlib
# cmap = cm.get_cmap('plasma', num_regions)
cmap = cm.get_cmap('gist_rainbow', num_regions)

# I want odd numbers from 345 to 384
region_indices = np.arange(345, 385, 2)

# Shuffle the region indices for random color assignment
np.random.seed(27)
shuffled_indices = region_indices.copy()
np.random.shuffle(shuffled_indices)

# Create a mapping from original region index to random color index
index_to_color_idx = {region: i for i, region in enumerate(shuffled_indices)}

# Iterate over each .obj file and add it to the meshes list
for i in region_indices:
    file_path = f"{file_base}{i}.obj"

    # Read the .obj file into a mesh
    mesh = pv.read(file_path)

    # Assign a scalar index corresponding to a shuffled color
    color_idx = index_to_color_idx[i]
    mesh.point_data['colors'] = np.full(mesh.n_points, color_idx)
    
    meshes.append(mesh)

# Combine all meshes into a single one
combined_mesh = meshes[0]
for mesh in meshes[1:]:
    combined_mesh += mesh

# Visualize the combined mesh
plotter = pv.Plotter()
# Add the mesh with custom colors (map the region index to region_colors)
plotter.add_mesh(combined_mesh, scalars="colors", cmap=cmap, show_edges=False)

plotter.show()
# Out:
# /var/folders/rn/z0683sns3tz7b_k0cbf8ft8w0000gq/T/ipykernel_28589/117880928.py:19: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('gist_rainbow', num_regions)
# Widget(value='<iframe src="http://localhost:59285/index.html?ui=P_0x31f9a37f0_16&reconnect=auto" class="pyvist…

# %%
import os
import numpy as np
import pyvista as pv
from glob import glob
from matplotlib.colors import ListedColormap

# Path to the folder containing the .obj files
obj_folder = "individual_meshes"
file_base = f"{obj_folder}/atlas_aicha_subcortex"

# I want odd numbers from 345 to 384
region_indices = np.arange(345, 385, 2)

# Define which region to highlight
highlight_index = 383

# List to store meshes
meshes = []

# Define a custom 2-color colormap: gray60 and bright red (or any highlight color)
custom_cmap = ListedColormap(["lightgray", "crimson"])  # gray for background, crimson for highlighted region

# Iterate over each .obj file and assign color index
for i in region_indices:
    file_path = f"{file_base}{i}.obj"

    # Read the .obj file into a mesh
    mesh = pv.read(file_path)

    # Set color index: 1 for highlight, 0 for others
    color_idx = 1 if i == highlight_index else 0
    mesh.point_data['colors'] = np.full(mesh.n_points, color_idx)

    meshes.append(mesh)

# Combine all meshes into a single one
combined_mesh = meshes[0]
for mesh in meshes[1:]:
    combined_mesh += mesh

# Visualize the combined mesh
plotter = pv.Plotter()
plotter.add_mesh(combined_mesh, scalars="colors", cmap=custom_cmap, show_edges=False)
plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:65096/index.html?ui=P_0x307e9e1c0_18&reconnect=auto" class="pyvist…
